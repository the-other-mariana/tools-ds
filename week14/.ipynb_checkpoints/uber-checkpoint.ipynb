# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sea
import numpy as np

# %%
url = 'res/uber.xlsx'
xls = pd.ExcelFile(url)
df1 = pd.read_excel(xls, 'Copyright')
df2 = pd.read_excel(xls, 'Data Dictionary')
df3 = pd.read_excel(xls, 'Switchbacks')

display(df1.head())
display(df2.head(14))
display(df3.head())
# Out:
#       Innovation at Uber: The Launch of Express POOL  Unnamed: 1  Unnamed: 2  \
# 0              Harvard Business School Case  619-003         NaN         NaN
# 1                                Courseware: 619-702         NaN         NaN
# 2                                REV: August 6, 2020         NaN         NaN
# 3  This courseware  was prepared solely as the ba...         NaN         NaN
# 4                                                NaN         NaN         NaN
#
#    Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#          Data Dictionary Unnamed: 1  \
# ...

# %% [markdown]
# ## Questions
#
# ### 1. What is the effect of extending the waiting time from 2  to 5 min on the total of completed trips / proportion of trips correclty matched / driver's earnings?
#
# ### 2. From a quantitative point of view, what would you recommend to Stock? Should he increase the waiting time in the 6 cities? ¿When does the increment should be applied?
#
# ### 3. Evaluate the Express project: what was done right by Uber? What could have improved?

# %%
wait2 = df3[df3['wait_time'].str.contains('2')]
wait2
# Out:
#     city_id        period_start wait_time  treat  commute  trips_pool  \
# 0    Boston 2018-02-19 07:00:00    2 mins  False     True        1415
# 2    Boston 2018-02-19 12:20:00    2 mins  False    False        1362
# 4    Boston 2018-02-19 17:40:00    2 mins  False    False        1371
# 6    Boston 2018-02-19 23:00:00    2 mins  False    False        1216
# 8    Boston 2018-02-20 04:20:00    2 mins  False    False        1248
# ..      ...                 ...       ...    ...      ...         ...
# 116  Boston 2018-03-04 04:20:00    2 mins  False    False        1156
# 118  Boston 2018-03-04 09:40:00    2 mins  False    False        1151
# 120  Boston 2018-03-04 15:00:00    2 mins  False    False        1393
# 122  Boston 2018-03-04 20:20:00    2 mins  False    False        1303
# 124  Boston 2018-03-05 01:40:00    2 mins  False    False        1170
#
#      trips_express  rider_cancellations  total_driver_payout  total_matches  \
# ...

# %%
wait5 = df3[df3['wait_time'].str.contains('5')]
wait5
# Out:
#     city_id        period_start wait_time  treat  commute  trips_pool  \
# 1    Boston 2018-02-19 09:40:00    5 mins   True    False        1461
# 3    Boston 2018-02-19 15:00:00    5 mins   True     True        1984
# 5    Boston 2018-02-19 20:20:00    5 mins   True    False        1401
# 7    Boston 2018-02-20 01:40:00    5 mins   True    False        1691
# 9    Boston 2018-02-20 07:00:00    5 mins   True     True        1815
# ..      ...                 ...       ...    ...      ...         ...
# 117  Boston 2018-03-04 07:00:00    5 mins   True    False        1515
# 119  Boston 2018-03-04 12:20:00    5 mins   True    False        1818
# 121  Boston 2018-03-04 17:40:00    5 mins   True    False        1718
# 123  Boston 2018-03-04 23:00:00    5 mins   True    False        1157
# 125  Boston 2018-03-05 04:20:00    5 mins   True    False        1360
#
#      trips_express  rider_cancellations  total_driver_payout  total_matches  \
# ...

# %%
wait = [wait2, wait5]
cols = ['trips_express', 'trips_pool', 'rider_cancellations']
d = {c: [] for c in cols}
for i in range(2):
    for c in cols:
        val = wait[i][c].sum()
        d[c].append(val)
d
# Out:
# {'trips_express': [164535, 152421],
#  'trips_pool': [85385, 92024],
#  'rider_cancellations': [10417, 11978]}

# %%
stats = list(d.values())
factor = 1000
stats = [list(np.array(s)/factor) for s in stats]
stats
# Out:
# [[164.535, 152.421], [85.385, 92.024], [10.417, 11.978]]

# %%
from matplotlib import cm
cmap1 = cm.get_cmap("tab20b")
'''
top = 
bottom = 
deciles = int((top - bottom) / 10)
'''

w = 0.75
xs = list(np.arange(0, len(stats[0])))
colors = [(0,0.3,1,0.5), (0,0.8,1,0.5), (1,0,0,0.5), (0.7, 0.7, 0.7, 0.5)]
labels = ['Express Trips', 'Pool Trips', 'Cancelled']
fig2 = plt.figure(figsize=(15, 6))
ax2 = fig2.add_subplot(1,1,1)

lower = [0, 0]
points = []
offset = [-0.5, 0.5]

for t in range(len(stats)+1):
    
    if t > 0:
        lower_vals = [max(stats[s]) for s in range(t-1, -1, -1)]
        val = sum(lower_vals)
        lower = [val, val]
        height = abs(min(stats[t-1])- max(stats[t-1]))
        perc = (stats[t-1][1] - stats[t-1][0]) / max(stats[t-1]) * 100
        x = np.array([stats[t-1].index(min(stats[t-1]))])
        txt = str(bool(perc >= 0)*'-') + f"{perc:.1f}%"
        ax2.barh(x, height, height=w, zorder=3, left=lower-height, color=colors[-1])
        ax2.annotate(txt, (lower[v]-height, x + (len(txt)*0.04)/2.0), fontsize=14, rotation=-90, color='black')
        points.append(list(lower-height))
    if t == len(stats):
        #points.append(lower)
        break
    for v in range(len(stats[t])):
        ax2.barh(np.array(xs[v]), stats[t][v], height=w, zorder=3, left=lower, color=colors[t])
        ax2.annotate(labels[t], (stats[t][v]*0.1 + lower[v], np.array(xs[v]) + (len(labels[t])*0.035)/2.0), fontsize=14, rotation=-90, color='white')
        points.append(list(lower))

points = np.array(points).reshape(np.array(points).shape[0]*np.array(points).shape[1])

points=list(set(points))

ax2.set_yticks(xs)
ax2.set_yticklabels(['2 min', '5 min'], fontsize=14)
ax2.grid(zorder=0, axis='x')
#plt.ylim((bottom, top))
plt.xticks(points[1:])
ax2.set_xticklabels([f"{int(p)}" for p in points[1:]], rotation=-90)
ax2.set_title("Total Trips & Cancellations: 2min vs 5min wait time", fontsize=14)
plt.xlabel("Amount of Trips (Thousands)", fontsize=14)
plt.ylabel("Waiting Time", fontsize=14, rotation=-90)
plt.gca().invert_yaxis()

plt.show()

fig2.tight_layout()
fig2.savefig('images/' + '1_1' + '.png', dpi=500)

# %%
wait = [wait2, wait5]
cols = ['total_matches', 'total_double_matches']
d = {c: [] for c in cols}
for i in range(2):
    for c in cols:
        val = wait[i][c].sum()
        d[c].append(val)
d
# Out:
# {'total_matches': [165892, 153613], 'total_double_matches': [81091, 85537]}

# %%
stats = list(d.values())
factor = 1000
stats = [list(np.array(s)/factor) for s in stats]
stats
# Out:
# [[165.892, 153.613], [81.091, 85.537]]

# %%
w = 0.75
xs = list(np.arange(0, len(stats[0])))
colors = [(0,0.3,1,0.5), (0,0.8,1,0.5), (1,0,0,0.5), (0.7, 0.7, 0.7, 0.5)]
labels = ['Matches', 'Double Matches']
fig2 = plt.figure(figsize=(15, 6))
ax2 = fig2.add_subplot(1,1,1)

lower = [0, 0]
points = []
offset = [-0.5, 0.5]

for t in range(len(stats)+1):
    
    if t > 0:
        lower_vals = [max(stats[s]) for s in range(t-1, -1, -1)]
        val = sum(lower_vals)
        lower = [val, val]
        height = abs(min(stats[t-1])- max(stats[t-1]))
        perc = (stats[t-1][1] - stats[t-1][0]) / max(stats[t-1]) * 100
        x = np.array([stats[t-1].index(min(stats[t-1]))])
        txt = str(bool(perc >= 0)*'-') + f"{perc:.1f}%"
        ax2.barh(x, height, height=w, zorder=3, left=lower-height, color=colors[-1])
        ax2.annotate(txt, (lower[v]-height - 0.2, x + (len(txt)*0.04)/2.0), fontsize=14, rotation=-90, color='black')
        points.append(list(lower-height))
    if t == len(stats):
        points.append(lower)
        break
    for v in range(len(stats[t])):
        ax2.barh(np.array(xs[v]), stats[t][v], height=w, zorder=3, left=lower, color=colors[t])
        ax2.annotate(labels[t], (stats[t][v]*0.1 + lower[v], np.array(xs[v]) + (len(labels[t])*0.045)/2.0), fontsize=14, rotation=-90, color='white')
        points.append(list(lower))

points = np.array(points).reshape(np.array(points).shape[0]*np.array(points).shape[1])
points=list(set(points))

ax2.set_yticks(xs)
ax2.set_yticklabels(['2 min', '5 min'], fontsize=14)
ax2.grid(zorder=0, axis='x')
#plt.ylim((bottom, top))
plt.xticks(points[1:])
ax2.set_xticklabels([f"{int(p)}" for p in points[1:]], rotation=-90)
ax2.set_title("Total Matches: 2min vs 5min wait time", fontsize=14)
plt.xlabel("Amount of Matches (Thousands)", fontsize=14)
plt.ylabel("Waiting Time", fontsize=14, rotation=-90)
plt.gca().invert_yaxis()
plt.show()
fig2.tight_layout()
fig2.savefig('images/' + '1_2' + '.png', dpi=500)

# %%
wait = [wait2, wait5]
cols = ['total_driver_payout']
d = {c: [] for c in cols}
for i in range(2):
    for c in cols:
        val = wait[i][c].sum()
        d[c].append(val)
d
# Out:
# {'total_driver_payout': [1845348.052074323, 1712541.7505539835]}

# %%
stats = list(d.values())
factor = 10000
stats = [list(np.array(s)/factor) for s in stats]
stats
# Out:
# [[184.5348052074323, 171.25417505539835]]

# %%
w = 0.75
xs = list(np.arange(0, len(stats[0])))
colors = [(0,0.3,1,0.5), (0,0.8,1,0.5), (1,0,0,0.5), (0.7, 0.7, 0.7, 0.5)]
labels = ['Driver\'s Pay']
fig2 = plt.figure(figsize=(15, 6))
ax2 = fig2.add_subplot(1,1,1)

lower = [0, 0]
points = []
offset = [-0.5, 0.5]

for t in range(len(stats)+1):
    
    if t > 0:
        lower_vals = [max(stats[s]) for s in range(t-1, -1, -1)]
        val = sum(lower_vals)
        lower = [val, val]
        height = abs(min(stats[t-1])- max(stats[t-1]))
        perc = (stats[t-1][1] - stats[t-1][0]) / max(stats[t-1]) * 100
        x = np.array([stats[t-1].index(min(stats[t-1]))])
        txt = str(bool(perc >= 0)*'-') + f"{perc:.1f}%"
        ax2.barh(x, height, height=w, zorder=3, left=lower-height, color=colors[-1])
        ax2.annotate(txt, (lower[v]-height - 0.2, x + (len(txt)*0.04)/2.0), fontsize=14, rotation=-90, color='black')
        points.append(list(lower-height))
    if t == len(stats):
        points.append(lower)
        break
    for v in range(len(stats[t])):
        ax2.barh(np.array(xs[v]), stats[t][v], height=w, zorder=3, left=lower, color=colors[t])
        ax2.annotate(labels[t], (stats[t][v]*0.1 + lower[v], np.array(xs[v]) + (len(labels[t])*0.035)/2.0), fontsize=14, rotation=-90, color='white')
        points.append(list(lower))

points = np.array(points).reshape(np.array(points).shape[0]*np.array(points).shape[1])
points=list(set(points))

ax2.set_yticks(xs)
ax2.set_yticklabels(['2 min', '5 min'], fontsize=14)
ax2.grid(zorder=0, axis='x')
#plt.ylim((bottom, top))
plt.xticks(points[1:])
ax2.set_xticklabels([f"{int(p)}" for p in points[1:]], rotation=-90)
ax2.set_title("Driver's Pay: 2min vs 5min wait time", fontsize=14)
plt.xlabel("US Dollars (Thousands)", fontsize=14)
plt.ylabel("Waiting Time", fontsize=14, rotation=-90)
plt.gca().invert_yaxis()
plt.show()
fig2.tight_layout()
fig2.savefig('images/' + '1_3' + '.png', dpi=500)

# %%
cols = ['trips_express', 'trips_pool', 'rider_cancellations']
hrs_2 = {c: {h:0 for h in range(1,25)} for c in cols}
hrs_5 = {c: {h: 0 for h in range(1,25)} for c in cols}
hrs = [hrs_2, hrs_5]
for i in range(2):
    for c in cols:
        hr = wait[i]['period_start'].dt.hour
        wait[i][c]
        for h in range(1,25):
            # df where the hour is == h
            temp = wait[i][wait[i]['period_start'].dt.hour==h]
            hrs[i][c][h] = temp[c].sum()
hrs
# Out:
# [{'trips_express': {1: 16099,
#    2: 0,
#    3: 0,
#    4: 15937,
#    5: 0,
#    6: 0,
#    7: 22289,
#    8: 0,
#    9: 17457,
#    10: 0,
#    11: 0,
#    12: 18179,
#    13: 0,
#    14: 0,
#    15: 22688,
#    16: 0,
#    17: 18271,
#    18: 0,
#    19: 0,
#    20: 16468,
#    21: 0,
#    22: 0,
#    23: 17147,
#    24: 0},
#   'trips_pool': {1: 8205,
#    2: 0,
#    3: 0,
#    4: 8167,
#    5: 0,
#    6: 0,
#    7: 10557,
#    8: 0,
#    9: 9562,
#    10: 0,
#    11: 0,
#    12: 8963,
#    13: 0,
#    14: 0,
#    15: 10523,
#    16: 0,
#    17: 9891,
#    18: 0,
#    19: 0,
#    20: 10444,
#    21: 0,
#    22: 0,
#    23: 9073,
#    24: 0},
#   'rider_cancellations': {1: 965,
#    2: 0,
#    3: 0,
#    4: 896,
#    5: 0,
#    6: 0,
#    7: 1497,
#    8: 0,
#    9: 1102,
#    10: 0,
#    11: 0,
#    12: 1047,
#    13: 0,
#    14: 0,
#    15: 1569,
#    16: 0,
#    17: 1174,
#    18: 0,
#    19: 0,
#    20: 1161,
#    21: 0,
#    22: 0,
#    23: 1006,
#    24: 0}},
# ...

# %%
hr = wait[0]['period_start'].dt.hour==7
hr
# Out:
# 0       True
# 2      False
# 4      False
# 6      False
# 8      False
#        ...
# 116    False
# 118    False
# 120    False
# 122    False
# 124    False
# Name: period_start, Length: 63, dtype: bool

# %%
wait[0][wait[0]['period_start'].dt.hour==7]
# Out:
#     city_id        period_start wait_time  treat  commute  trips_pool  \
# 0    Boston 2018-02-19 07:00:00    2 mins  False     True        1415
# 18   Boston 2018-02-21 07:00:00    2 mins  False     True        1916
# 36   Boston 2018-02-23 07:00:00    2 mins  False     True        1178
# 54   Boston 2018-02-25 07:00:00    2 mins  False    False        1745
# 72   Boston 2018-02-27 07:00:00    2 mins  False     True        1473
# 90   Boston 2018-03-01 07:00:00    2 mins  False     True        1482
# 108  Boston 2018-03-03 07:00:00    2 mins  False    False        1348
#
#      trips_express  rider_cancellations  total_driver_payout  total_matches  \
# 0             3245                  256         34458.411634           3372
# 18            3469                  245         44871.105849           3575
# 36            3591                  228         34077.770113           3816
# 54            2496                  159         28170.199869           2510
# ...

# %%
wait[0][wait[0]['period_start'].dt.hour==7]['trips_express'].sum()
# Out:
# 22289

# %%
factor = 1000.0
fig = plt.figure( figsize=(12,10) )
grid = fig.add_gridspec(3,3)
axes = [None, None, None]
for i in range(3):
    ax = fig.add_subplot( grid[i,:] ) # plot that uses the first row and 3 cols
    axes[i] = ax

colors = [(0,0.3,1,1), (0,0.8,1,1), (1,0,0,0.5), (0.7, 0.7, 0.7, 0.5)]
labels = ['Express Trips', 'Pool Trips', 'Cancelled']
legs = ['2 min', '5 min']
cols = ['trips_express', 'trips_pool', 'rider_cancellations']

for c in range(len(cols)):
    for i in range(2):
        xs = list(range(1,25))
        full_keys = [k for k in hrs[i][cols[c]].keys() if hrs[i][cols[c]][k] != 0]
        full_vals = [hrs[i][cols[c]][k]/factor for k in hrs[i][cols[c]].keys() if hrs[i][cols[c]][k] != 0]

        axes[c].plot(full_keys, full_vals, marker='o', lw=4, ms=8, color=colors[i], label = legs[i])
        axes[c].set_title(f"{labels[c]}: 2 vs 5 min wait")
        axes[c].set_xticks(full_keys)
        axes[c].set_xticklabels([f"{k}:00 hrs" for k in full_keys])
        axes[c].grid(True, axis='y')
        axes[c].legend()
        axes[c].set_ylabel("Trips (Thousand)")
fig.tight_layout()
fig.savefig('images/' + '2' + '.png', dpi=500)
plt.show()
